# %% [markdown]
# <a href="https://colab.research.google.com/github/wangqian2149185/BMRB-API/blob/master/Sec02_readPDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project: Prediction chemical shift < = > structure
#
# ### **Personal project proposal since April 2024**
#
# #### **Composed by Qian Wang**
#
# Alphafold2's predition is quite impressive. But all of the predition was based on 1st primary structureof the peptide, which ignores the individual environment of the protien, such as (pH, temperature, ion strength, or even the presence of other molecules like ligand and so forth). Fortunately, the NMR assignment of the chemical shift from each atom of protein molecule is the closest the in vivo of the protein state. In addition, NMR spectrum contains tons of infomation of each atom of molecules that had never been fully digged in. Most of the info has been ignored, due to the complicated combination of each minor quantum effect (resultantly largely effect).
#
# This project is trying to predict from 2 directions in the methods of machine learnings and deep learnings by training the data from BMRB and PDB database:
#
# 1. predict NMR chemical shift based on a given structure (PDB format)
#
# 2. predict the structure from the acquired NMR chemical shift.
#
#
# Additionally, we will try to build a model of predicting 2nd structure, dihedral angle, or even the dynamics from chemical shift.
#
# **Table of contents**:
#
# 1. Reading data from BMRB
# 2. Reading data from PDB
# 3.

# %%
# install requests and biopython for later read
# !pip install requests
# !pip install biopython
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)
# Collecting biopython
#   Downloading biopython-1.83-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from biopython) (1.25.2)
# Installing collected packages: biopython
# Successfully installed biopython-1.83

# %%
# show all columns
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 2.0 Read the files from PDB database

# %% [markdown]
# ## 2.0.1 read index files

# %%
# read table where keep all BMRBid and PDB id from the drive. This is the table containing BMRB ID and PDB ID
path_BMRB_ID = "/content/drive/MyDrive/Colab Notebooks/BMRB_PDB_Project/rawdata/query_grid.csv"
df_query_CSV = pd.read_csv(path_BMRB_ID)

# %%
df_EntryID_PDB = df_query_CSV[['Entry_ID', 'pdb_ids']]

# %%
df_EntryID_PDB.head()
# Out:
#    Entry_ID    pdb_ids
# 0      4023  2SPZ,1Q2N
# 1      4052       1JOO
# 2      4053       1JOQ
# 3      4089       2DEF
# 4      4090       2EZH

# %% [markdown]
# ##2.0.2 read concurrently after sharding
# **Since Colab has only 2 cores, so I decided to run on my local MAC which has 8 cores and faster.**

# %%
import os
from concurrent.futures import ThreadPoolExecutor, as_completed
import requests
import pandas as pd
from Bio.PDB.MMCIF2Dict import MMCIF2Dict
from io import StringIO
from math import ceil

# Check the number of CPU cores in the system
num_cores = os.cpu_count()
print(f"Number of CPU cores available: {num_cores}")

# Set max_workers based on the number of CPU cores
max_workers = num_cores * 2  # or another multiplier based on your testing

def get_pdb_files_by_url(pdb_num):
    url_pre = "https://models.rcsb.org/v1/"
    url_post = "/full?encoding=cif&copy_all_categories=false&download=false"
    url = url_pre + pdb_num + url_post

    try:
        response = requests.get(url)
        response.raise_for_status()  # Check if the request was successful

        # Read the content into MMCIF2Dict
        dico = MMCIF2Dict(StringIO(response.text))
        df_temp = pd.DataFrame.from_dict(dico, orient='index').transpose()

        print(f"Successfully added PDB ID {pdb_num}.")
        return df_temp
    except requests.exceptions.RequestException as e:
        print(f"Request failed for PDB ID {pdb_num}: {e}")
    except Exception as e:
        print(f"Failed to process PDB ID {pdb_num}: {e}")
    return pd.DataFrame()  # Return an empty DataFrame on failure

def download_pdb_files_concurrently(pdb_ids, max_workers=10):
    df_BMRB_all = pd.DataFrame()
    chunk_size = ceil(len(pdb_ids) / max_workers)
    pdb_chunks = [pdb_ids[i:i + chunk_size] for i in range(0, len(pdb_ids), chunk_size)]

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_chunk = {executor.submit(download_chunk, chunk): chunk for chunk in pdb_chunks}

        for future in as_completed(future_to_chunk):
            try:
                df_temp = future.result()
                df_BMRB_all = pd.concat([df_BMRB_all, df_temp], ignore_index=True)
            except Exception as e:
                print(f"Error processing a chunk of PDB IDs: {e}")

    return df_BMRB_all

def download_chunk(chunk):
    df_chunk = pd.DataFrame()
    for pdb_id in chunk:
        df_temp = get_pdb_files_by_url(pdb_id)
        df_chunk = pd.concat([df_chunk, df_temp], ignore_index=True)
    return df_chunk

def main():
    # Load the PDB IDs from your CSV file
    path_BMRB_ID = "/content/drive/MyDrive/Colab Notebooks/BMRB_PDB_Project/rawdata/query_grid.csv"
    df_query_CSV = pd.read_csv(path_BMRB_ID)
    df_EntryID_PDB = df_query_CSV[['Entry_ID', 'pdb_ids']]

    # Prepare the list of PDB IDs
    pdb_ids = []
    for index, row in df_EntryID_PDB.iterrows():
        pdb_ids.extend(row['pdb_ids'].split(','))

    chunk_size = 200
    for i in range(0, len(pdb_ids), chunk_size):
        pdb_chunk = pdb_ids[i:i + chunk_size]

        # Download PDB files in parallel
        df_BMRB_all = download_pdb_files_concurrently(pdb_chunk, max_workers=max_workers)

        # Remove duplicates and reset index
        # df_BMRB_all = df_BMRB_all.drop_duplicates().reset_index(drop=True)

        # Save the DataFrame to a CSV file
        temp_path = f"/content/drive/MyDrive/Colab Notebooks/BMRB_PDB_Project/rawdata/df_PDB_{i//chunk_size + 1}.csv"
        df_BMRB_all.to_csv(temp_path, index=False)
        print(f"Successfully saved to {temp_path}!")

if __name__ == '__main__':
    main()
# Out:
# Number of CPU cores available: 2
# Successfully added PDB ID 1C05.
# Successfully added PDB ID 2SPZ.
# Successfully added PDB ID 1Q2N.
# Successfully added PDB ID 1HYJ.
# Successfully added PDB ID 1JOO.
# Successfully added PDB ID 1JM4.
# Successfully added PDB ID 1JR6.
# Successfully added PDB ID 1HYI.
# Successfully added PDB ID 1DOQ.
# Successfully added PDB ID 1ZRR.
# Successfully added PDB ID 1EIG.
# Successfully added PDB ID 1EIH.
# Successfully added PDB ID 1EOQ.
# Successfully added PDB ID 7HSC.
# Successfully added PDB ID 1KQQ.
# Successfully added PDB ID 2AN7.
# Successfully added PDB ID 1JOQ.
# Successfully added PDB ID 1CL4.
# Successfully added PDB ID 1LY7.
# Successfully added PDB ID 1DLZ.
# Successfully added PDB ID 1KD6.
# Successfully added PDB ID 1FPW.
# Successfully added PDB ID 1DV5.
# Successfully added PDB ID 1EE7.
# Successfully added PDB ID 2DEF.
# Successfully added PDB ID 1LS4.
# Successfully added PDB ID 1FHO.
# Successfully added PDB ID 2EZH.
# Successfully added PDB ID 1M58.
# Successfully added PDB ID 1A5J.
# Successfully added PDB ID 1JXS.
# Successfully added PDB ID 1E0E.
# Successfully added PDB ID 2LCP.
# Successfully added PDB ID 1G6E.
# Successfully added PDB ID 1NK2.
# Successfully added PDB ID 1H95.
# Successfully added PDB ID 1E91.
# Successfully added PDB ID 1RXR.
# Successfully added PDB ID 1E1U.
# Successfully added PDB ID 1EZY.
# Successfully added PDB ID 1E4U.
# Request failed for PDB ID 1LWM: ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# Successfully added PDB ID 1IJA.
# Successfully added PDB ID 1JGK.
# Successfully added PDB ID 1H67.
# Successfully added PDB ID 1BJX.
# Successfully added PDB ID 1BO0.
# Successfully added PDB ID 1E52.
# Successfully added PDB ID 1F2H.
# Successfully added PDB ID 1F43.
# Successfully added PDB ID 1G47.
# Successfully added PDB ID 1EH2.
# Successfully added PDB ID 1M31.
# Successfully added PDB ID 2IFE.
# Successfully added PDB ID 1B75.
# Successfully added PDB ID 1BLR.
# Successfully added PDB ID 1FO7.
# Successfully added PDB ID 1BCI.
# Successfully added PDB ID 2CPS.
# Successfully added PDB ID 1COU.
# Successfully added PDB ID 1KVZ.
# Successfully added PDB ID 1EKZ.
# Successfully added PDB ID 1G6P.
# Successfully added PDB ID 1B2T.
# Successfully added PDB ID 1BR0.
# Successfully added PDB ID 1G5V.
# Successfully added PDB ID 1RJA.
# Successfully added PDB ID 1FZT.
# Successfully added PDB ID 1HF9.
# Successfully added PDB ID 1BLQ.
# Successfully added PDB ID 1F96.
# Successfully added PDB ID 1KHM.
# Successfully added PDB ID 1CMZ.
# Successfully added PDB ID 1F3C.
# Successfully added PDB ID 1COK.
# Successfully added PDB ID 1G03.
# Successfully added PDB ID 1BA9.
# Successfully added PDB ID 1G9L.
# Successfully added PDB ID 1G7E.
# Successfully added PDB ID 1RK7.
# Successfully added PDB ID 1C15.
# Successfully added PDB ID 1MFN.
# Successfully added PDB ID 2M66.
# Successfully added PDB ID 1B6F.
# Successfully added PDB ID 1EYF.
# Successfully added PDB ID 2CPB.
# Successfully added PDB ID 1C3T.
# Successfully added PDB ID 1N02.
# Successfully added PDB ID 1XDX.
# Successfully added PDB ID 1KVV.
# Successfully added PDB ID 1QHK.
# Successfully added PDB ID 2TMP.
# Successfully added PDB ID 1KVN.
# Successfully added PDB ID 1SSN.
# Successfully added PDB ID 1JZU.
# Successfully added PDB ID 3BDO.
# Successfully added PDB ID 1I17.
# Successfully added PDB ID 1DCZ.
# Successfully added PDB ID 1BHI.
# Successfully added PDB ID 1JJR.
# Successfully added PDB ID 1BHU.
# Successfully added PDB ID 1DD2.
# Successfully added PDB ID 2BDO.
# Successfully added PDB ID 1IX5.
# Successfully added PDB ID 1HS7.
# Successfully added PDB ID 1HZE.
# Successfully added PDB ID 1EXK.
# Successfully added PDB ID 1I18.
# Successfully added PDB ID 2CNP.
# Successfully added PDB ID 1FM1.
# Successfully added PDB ID 1FLS.
# Successfully added PDB ID 1TBA.
# Successfully added PDB ID 1JWD.
# Successfully added PDB ID 1EII.
# Successfully added PDB ID 1CKV.
# Successfully added PDB ID 1I1S.
# Successfully added PDB ID 1ILY.
# Successfully added PDB ID 2NBI.
# Successfully added PDB ID 1CEJ.
# Successfully added PDB ID 1MYO.
# Successfully added PDB ID 1D8B.
# Successfully added PDB ID 1INZ.
# Successfully added PDB ID 1BQZ.
# Successfully added PDB ID 1K1C.
# Successfully added PDB ID 1D1N.
# Successfully added PDB ID 1H7Y.
# Successfully added PDB ID 1H6Q.
# Successfully added PDB ID 1KOS.
# Successfully added PDB ID 1HY8.
# Successfully added PDB ID 1CF4.
# Successfully added PDB ID 1D9S.
# Successfully added PDB ID 1ILO.Successfully added PDB ID 1BQ0.
#
# Successfully added PDB ID 1CX1.
# Successfully added PDB ID 1F3Y.
# Successfully added PDB ID 1BUQ.
# Successfully added PDB ID 1ZAC.
# Successfully added PDB ID 1IH9.
# Successfully added PDB ID 1N4C.
# Successfully added PDB ID 1F7W.
# Successfully added PDB ID 1CI5.
# Successfully added PDB ID 1F7X.
# Successfully added PDB ID 1UB1.
# Successfully added PDB ID 1D8J.
# Successfully added PDB ID 1IH0.
# Successfully added PDB ID 3MSP.
# Successfully added PDB ID 1R2A.
# Successfully added PDB ID 1JYT.
# Successfully added PDB ID 1IHQ.
# Successfully added PDB ID 2LEF.
# Successfully added PDB ID 1XPA.
# Successfully added PDB ID 1GH9.
# Successfully added PDB ID 1L3G.
# Successfully added PDB ID 1J9I.
# Successfully added PDB ID 1IIO.
# Successfully added PDB ID 1L6E.
# Successfully added PDB ID 1CR8.
# Successfully added PDB ID 1B4R.
# Successfully added PDB ID 1DV0.
# Successfully added PDB ID 1QPU.
# Successfully added PDB ID 1IK0.
# Successfully added PDB ID 2IF1.
# Successfully added PDB ID 1S62.
# Successfully added PDB ID 1DUJ.
# Successfully added PDB ID 2MOB.
# Successfully added PDB ID 2NMB.
# Successfully added PDB ID 3EZA.
# Successfully added PDB ID 1JAJ.
# Successfully added PDB ID 1VRC.
# Successfully added PDB ID 1ICH.
# Successfully added PDB ID 1FI6.
# Successfully added PDB ID 1QJT.
# Successfully added PDB ID 1DS9.
# Successfully added PDB ID 1I4V.
# Successfully added PDB ID 1PLO.
# Successfully added PDB ID 1M9L.
# Successfully added PDB ID 1GHT.
# Successfully added PDB ID 1JBA.
# Successfully added PDB ID 1F6U.
# Successfully added PDB ID 1UD7.
# Successfully added PDB ID 1HX7.
# Successfully added PDB ID 1OM2.
# Successfully added PDB ID 7HSC.
# Successfully added PDB ID 1CL4.
# Successfully added PDB ID 1JFJ.
# Successfully added PDB ID 1JFK.
# Successfully added PDB ID 1D2L.
# Successfully added PDB ID 1B2I.
# Successfully added PDB ID 1D5G.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-c725b66dbd1c> in download_pdb_files_concurrently(pdb_ids, max_workers)
#      44
# ---> 45         for future in as_completed(future_to_chunk):
#      46             try:
#
# /usr/lib/python3.10/concurrent/futures/_base.py in as_completed(fs, timeout)
#     244
# --> 245             waiter.event.wait(wait_timeout)
#     246
#
# /usr/lib/python3.10/threading.py in wait(self, timeout)
#     606             if not signaled:
# --> 607                 signaled = self._cond.wait(timeout)
#     608             return signaled
#
# /usr/lib/python3.10/threading.py in wait(self, timeout)
#     319             if timeout is None:
# --> 320                 waiter.acquire()
#     321                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-c725b66dbd1c> in <cell line: 87>()
#      86
#      87 if __name__ == '__main__':
# ---> 88     main()
#
# <ipython-input-23-c725b66dbd1c> in main()
#      75
#      76         # Download PDB files in parallel
# ---> 77         df_BMRB_all = download_pdb_files_concurrently(pdb_chunk, max_workers=max_workers)
#      78
#      79         # Remove duplicates and reset index
#
# <ipython-input-23-c725b66dbd1c> in download_pdb_files_concurrently(pdb_ids, max_workers)
#      40     pdb_chunks = [pdb_ids[i:i + chunk_size] for i in range(0, len(pdb_ids), chunk_size)]
#      41
# ---> 42     with ThreadPoolExecutor(max_workers=max_workers) as executor:
#      43         future_to_chunk = {executor.submit(download_chunk, chunk): chunk for chunk in pdb_chunks}
#      44
#
# /usr/lib/python3.10/concurrent/futures/_base.py in __exit__(self, exc_type, exc_val, exc_tb)
#     647
#     648     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 649         self.shutdown(wait=True)
#     650         return False
#     651
#
# /usr/lib/python3.10/concurrent/futures/thread.py in shutdown(self, wait, cancel_futures)
#     233         if wait:
#     234             for t in self._threads:
# --> 235                 t.join()
#     236     shutdown.__doc__ = _base.Executor.shutdown.__doc__
#
# /usr/lib/python3.10/threading.py in join(self, timeout)
#    1094
#    1095         if timeout is None:
# -> 1096             self._wait_for_tstate_lock()
#    1097         else:
#    1098             # the behavior of a negative timeout isn't documented, but
#
# /usr/lib/python3.10/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1114
#    1115         try:
# -> 1116             if lock.acquire(block, timeout):
#    1117                 lock.release()
#    1118                 self._stop()
#
# KeyboardInterrupt:
